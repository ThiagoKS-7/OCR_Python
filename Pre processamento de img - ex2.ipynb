# %% [markdown]
# # Pré Processamento de imagens

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
img = cv2.imread('Imagens/img-process.jpg')
plt.imshow(img)
plt.show()
cv2.imshow('img', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray)
plt.show()
cv2.imshow('gray', gray)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Thresholding (finalmente \o/)

# %% [markdown]
# # Simples

# %%
img = cv2.imread("Imagens/trecho-livro.jpg")
plt.imshow(img)
plt.show()
cv2.imshow('img', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray)
plt.show()
cv2.imshow('gray', gray)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import pytesseract

val, thresh = cv2.threshold(gray,142,255, cv2.THRESH_BINARY) # img, thresh, máximo e tipo

cv2.imshow('thresh', thresh)
cv2.waitKey(0)
cv2.destroyAllWindows()
plt.imshow(thresh)
plt.show()

config = '--psm 6'
texto = pytesseract.image_to_string(thresh, lang='por', config=config)
print(texto)
# Out:
# A inteligência humana É caracterizada pela capacidade de se
# adaptar a mudanças. É resultado de gerações de seleção natural
# Sobre indivíduos com capacidade para lídar com as novas ciruns-
# tâncias. Não devemos, portanto, temer as transformações. Preci-
# samos aperas fazer com que elas operem em nosso benefício.

# %% [markdown]
# # Método de Otsu

# %%
import pytesseract
val, otsu = cv2.threshold(gray, 0,255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)
cv2.imshow('otsu', otsu)
cv2.waitKey(0)
cv2.destroyAllWindows()
print(f' valor do thresh: {val}')
plt.imshow(otsu)
plt.show()
config = '--psm 6'
texto = pytesseract.image_to_string(otsu, lang='por', config=config)
print(texto)
# Out:
#  valor do thresh: 138.0
# AA inteligência humana É caracterizada pela capacídade de se
# adaptar a mudanças. É resultado de gerações de seleção natural
# Sobre indivíduos com capacidade para lídar com as novas ciruns-
# tâncias. Não devemos, portanto, temer as transformações. Preci-
# samos apenas fazer com que elas operem em nosso benefício.

# %%
img2 = cv2.imread('Imagens/img-process.jpg')
gray2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
val2, otsu2 = cv2.threshold(gray2, 0,255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)
cv2.imshow('otsu', otsu2)
cv2.waitKey(0)
cv2.destroyAllWindows()
print(f' valor do thresh: {val2}')
plt.imshow(otsu2)
plt.show()

texto2 = pytesseract.image_to_string(otsu2, lang='por', config=config)
print(texto2)
# Out:
#  valor do thresh: 154.0
# processamento
# de imagem

# %%
img3 = cv2.imread('Imagens/receita01.jpg')
gray3 = cv2.cvtColor(img3, cv2.COLOR_BGR2GRAY)
val3, otsu3 = cv2.threshold(gray3, 133, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)
cv2.imshow('otsu', otsu3)
cv2.waitKey(0)
cv2.destroyAllWindows()
print(f' valor do thresh: {val3}')
plt.imshow(otsu3)
plt.show()

texto3 = pytesseract.image_to_string(otsu3, lang='por', config=config)
print(texto3)

img4 = cv2.imread('Imagens/receita01.jpg')
gray4 = cv2.cvtColor(img4, cv2.COLOR_BGR2GRAY)
cv2.imshow('otsu', gray4)
cv2.waitKey(0)
cv2.destroyAllWindows()
plt.imshow(gray4)
plt.show()
texto4 = pytesseract.image_to_string(gray4, lang='por', config=config)
print(texto4)
# Out:
#  valor do thresh: 119.0
# TO-DE-LO
#
# Peneire junto a farinha, a maisena e o fermento e reserve.
#
# Bata as claras em neve. Adicione as gemas uma a uma.
# Acrescente o açúcar, sempre batendo bem. Junte a água, alter-
# nando-a com a mistura de farinha.
#
# Misture rapidamente, coloque em uma assadeira untada e
# “orrada com papel-manteiga. Asse em forno regular.
# 1 O - D En
#
# Peneire junto a farinha, a maisena e o fermento e reserve.
#
# Bata as claras em neve. Adicione as gemas uma a uma.
# Acrescente o açúcar, sempre batendo bem. Junte a água, alter-
# nando-a com a mistura de farinha.
#
# Misture rapidamente, coloque em uma assadeira untada e
# forrada com papel-manteiga. Asse em forno regular.

# %% [markdown]
# # Thresh Adaptativa

# %%
img = cv2.imread('Imagens/livro02.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
adap = cv2.adaptiveThreshold(gray, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 11, 9)
cv2.imshow('adap', adap)
cv2.waitKey(0)
cv2.destroyAllWindows()
plt.imshow(adap)
plt.show()

texto = pytesseract.image_to_string(adap, lang='por', config=config)
print(texto)
# Out:
# a inteligência humana É caracterizada pela capacidade de se
# adoptra mudanças- É resultado de gerações d deção nº ,.,s
# a7 e seleção
# sobre Á ova: uns-
# bre indivíduos com capacidade para lidarcomas o
# incias. Não dev rm“ “ºsc:í'P cÍ
# tinc levemos, portanto, temer as transfo! '
# samos apenas la ss e |
# penas fazer com que elas operem em no: bç "
# o benefíci:
# io.
